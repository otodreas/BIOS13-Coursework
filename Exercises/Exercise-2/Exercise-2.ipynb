# %%
c(1)
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[1], line 1
#
# ----> 1 c(1)
#
#
#
# NameError: name 'c' is not defined
